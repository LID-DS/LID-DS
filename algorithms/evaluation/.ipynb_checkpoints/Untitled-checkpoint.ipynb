# %%
from algorithms.persistance import load_from_json

import os
import pandas as pd
import sqlite3 as sql
import matplotlib.pyplot as plt

# %%
def convert_to_df(path: str):
    results = load_from_json(path)
    config_list = []
    performance_list = []
    for result in results:
        config_list.append(result['config'])
        performance_list.append(result['performance'])
    config = pd.DataFrame(config_list)
    performance = pd.DataFrame(performance_list)
    result_list = pd.concat([performance, config], axis=1)
    return result_list

# %%
result_list = convert_to_df('../persistent_data/lstm.json')
result_list
# Out:
#      true_positives  false_positives  true_negatives  false_negatives  \
# 0               172                0         1227918           194417
# 1               274               29         2670371          2095219
# 2                 0                1         3396126          1474597
# 3               172                0         1226104           194417
# 4                 0                1         2833009           285051
# ..              ...              ...             ...              ...
# 186             564               14        15571956          1815734
# 187             166               19        12744090          1104285
# 188            1801                1        13496612          1755783
# 189            1018                7        15570239          1815280
# 190            3399              120        14336020          4572120
#
#      alarm_count  exploit_count  detection_rate  \
# 0            172            174        0.988506
# 1             51             98        0.520408
# 2              0            155        0.000000
# 3            172            174        0.988506
# 4              0            100        0.000000
# ..           ...            ...             ...
# 186          101            103        0.980583
# 187           98             98        1.000000
# 188          137            137        1.000000
# 189          103            103        1.000000
# 190          100            100        1.000000
#
#      consecutive_false_positives_normal  consecutive_false_positives_exploits  \
# 0                                     0                                     0
# 1                                    26                                     3
# 2                                     1                                     0
# 3                                     0                                     0
# 4                                     1                                     0
# ..                                  ...                                   ...
# 186                                  13                                     1
# 187                                  19                                     0
# 188                                   1                                     0
# 189                                   7                                     0
# 190                                 116                                     4
#
#        recall  precision_with_cfa  precision_with_syscalls  \
# 0    0.988506            1.000000                 1.000000
# 1    0.520408            0.637500                 0.637500
# 2    0.000000            0.000000                 0.000000
# 3    0.988506            1.000000                 1.000000
# 4    0.000000            0.000000                 0.000000
# ..        ...                 ...                      ...
# 186  0.980583            0.878261                 0.878261
# 187  1.000000            0.837607                 0.837607
# 188  1.000000            0.992754                 0.992754
# 189  1.000000            0.936364                 0.936364
# 190  1.000000            0.454545                 0.454545
#
#                   scenario  ngram  batch_size  embedding_size  return_value  \
# 0           CVE-2017-7529/      4        1024               6          True
# 1      Bruteforce_CWE-307/      4        1024               6          True
# 2           CVE-2012-2122/      4        1024               6          True
# 3           CVE-2017-7529/      6        1024               6          True
# 4           CVE-2014-0160/      6        1024               6          True
# ..                     ...    ...         ...             ...           ...
# 186           PHP_CWE-434/      6        1024               8          True
# 187         CVE-2019-5418/      8        1024               8          True
# 188         CVE-2018-3760/      8        1024               8          True
# 189           PHP_CWE-434/      8        1024               8          True
# 190  SQL_Injection_CWE-89/      8        1024               8          True
#
#      thread_change_flag  time_delta  detection_time
# 0                  True       False       15.711918
# 1                  True       False       50.891472
# 2                  True       False       47.202630
# 3                  True       False       16.018071
# 4                  True       False       34.263841
# ..                  ...         ...             ...
# 186                True       False      176.142924
# 187                True       False      127.150144
# 188                True       False      169.928648
# 189                True       False      162.617787
# 190                True       False      209.909717
#
# [191 rows x 20 columns]

# %%
conn = sql.connect('eval.db')
result_list.to_sql('eval', conn)

# %%
conn = sql.connect('eval.db')
result = pd.read_sql('SELECT scenario, \
                             ngram, \
                             embedding_size as embed, \
                             return_value as rv, \
                             thread_change_flag as tcf, \
                             time_delta as td, \
                             ROUND(AVG(consecutive_false_positives_normal),2) as fp_norm, \
                             AVG(consecutive_false_positives_exploits) as fp_ex, \
                             SUM(consecutive_false_positives_normal + consecutive_false_positives_exploits) as fp_sum, \
                             ROUND(AVG(detection_rate),2) as DR\
                     FROM eval \
                     GROUP BY scenario, \
                              ngram, \
                              embedding_size, \
                              rv, \
                              tcf, \
                              td \
                     HAVING DR > 0.5 \
                     ORDER BY DR desc, \
                              fp_sum asc', conn)

# %%
result
# Out:
#                  scenario  ngram  embed  rv  tcf  td  fp_norm     fp_ex  \
# 0          CVE-2019-5418/      6      6   1    0   0     1.50  0.000000
# 1          CVE-2019-5418/      4      8   1    1   0     2.50  0.000000
# 2          CVE-2018-3760/      6      6   1    1   0     4.00  0.000000
# 3   SQL_Injection_CWE-89/      6      6   1    0   0     6.00  0.500000
# 4          CVE-2018-3760/      8      8   1    1   0     7.50  0.000000
# 5            PHP_CWE-434/      8      6   1    1   0     7.50  0.000000
# 6          CVE-2018-3760/      4      8   1    1   0     7.50  0.500000
# 7          CVE-2018-3760/      8      8   1    0   0     8.00  0.000000
# 8   SQL_Injection_CWE-89/      8      8   1    0   0     8.50  0.000000
# 9          CVE-2018-3760/      6      8   1    1   0     9.00  0.000000
# 10         CVE-2018-3760/      8      6   1    0   0     9.00  0.000000
# 11           PHP_CWE-434/      8      8   1    1   0     8.00  1.000000
# 12         CVE-2018-3760/      4      8   1    0   0    10.00  0.500000
# 13         CVE-2018-3760/      6      6   1    0   0    13.00  0.000000
# 14         CVE-2018-3760/      6      8   1    0   0    12.50  0.500000
# 15         CVE-2019-5418/      8      8   1    1   0    16.50  0.000000
# 16           PHP_CWE-434/      4      6   1    1   0    16.50  0.000000
# 17  SQL_Injection_CWE-89/      8      6   1    0   0    19.50  0.000000
# 18  SQL_Injection_CWE-89/      4      6   1    0   0    20.50  0.000000
# 19         CVE-2018-3760/      8      6   1    1   0    24.50  0.500000
# 20         CVE-2018-3760/      4      6   1    1   0    23.50  2.500000
# 21  SQL_Injection_CWE-89/      6      8   1    1   0    28.00  0.500000
# 22  SQL_Injection_CWE-89/      4      8   1    0   0    29.50  0.000000
# 23         CVE-2018-3760/      4      6   1    0   0    31.50  1.500000
# 24         CVE-2019-5418/      4      6   1    0   0    33.50  0.500000
# 25  SQL_Injection_CWE-89/      4      6   1    1   0    35.00  2.500000
# 26  SQL_Injection_CWE-89/      6      6   1    1   0    42.00  0.500000
# 27           PHP_CWE-434/      4      8   1    1   0    46.00  1.000000
# 28  SQL_Injection_CWE-89/      4      8   1    1   0    54.00  3.000000
# 29  SQL_Injection_CWE-89/      8      8   1    1   0    68.50  2.000000
# 30  SQL_Injection_CWE-89/      6      8   1    0   0    76.50  3.500000
# 31  SQL_Injection_CWE-89/      8      6   1    1   0   111.50  4.000000
# 32         CVE-2017-7529/      4      6   1    1   0     0.00  0.000000
# 33         CVE-2017-7529/      4      8   1    1   0     0.00  0.000000
# 34         CVE-2017-7529/      4      8   1    0   0     0.50  0.000000
# 35         CVE-2017-7529/      8      6   1    0   0     1.00  0.000000
# 36         CVE-2017-7529/      4      6   1    0   0     2.00  0.000000
# 37         CVE-2017-7529/      6      6   1    0   0     1.00  0.000000
# 38         CVE-2017-7529/      6      6   1    1   0     1.00  0.000000
# 39         CVE-2017-7529/      8      8   1    0   0     1.50  0.000000
# 40         CVE-2017-7529/      6      8   1    1   0     3.00  0.000000
# 41         CVE-2017-7529/      8      8   1    1   0     3.00  0.000000
# 42         CVE-2017-7529/      8      6   1    1   0     4.50  0.000000
# 43           PHP_CWE-434/      6      8   1    1   0    10.50  0.500000
# 44         CVE-2012-2122/      4      8   1    1   0    17.00  1.500000
# 45           PHP_CWE-434/      6      6   1    0   0    13.00  1.500000
# 46           PHP_CWE-434/      8      8   1    0   0     7.50  1.000000
# 47           PHP_CWE-434/      8      6   1    0   0     9.00  0.500000
# 48           PHP_CWE-434/      6      6   1    1   0    10.00  0.000000
# 49           PHP_CWE-434/      4      8   1    0   0    15.00  1.000000
# 50    Bruteforce_CWE-307/      8      8   1    1   0    11.50  2.000000
# 51    Bruteforce_CWE-307/      4      8   1    1   0    36.00  2.500000
# 52    Bruteforce_CWE-307/      4      6   1    1   0    22.33  2.666667
# 53         CVE-2019-5418/      4      8   1    0   0     2.00  0.000000
#
#     fp_sum    DR
# 0        3  1.00
# 1        5  1.00
# 2        8  1.00
# 3       13  1.00
# 4       15  1.00
# 5       15  1.00
# 6       16  1.00
# 7       16  1.00
# 8       17  1.00
# 9       18  1.00
# 10      18  1.00
# 11      18  1.00
# 12      21  1.00
# 13      26  1.00
# 14      26  1.00
# 15      33  1.00
# 16      33  1.00
# 17      39  1.00
# 18      41  1.00
# 19      50  1.00
# 20      52  1.00
# 21      57  1.00
# 22      59  1.00
# 23      66  1.00
# 24      68  1.00
# 25      75  1.00
# 26      85  1.00
# 27      94  1.00
# 28     114  1.00
# 29     141  1.00
# 30     160  1.00
# 31     231  1.00
# 32       0  0.99
# 33       0  0.99
# 34       1  0.99
# 35       1  0.99
# 36       2  0.99
# 37       2  0.99
# 38       3  0.99
# 39       3  0.99
# 40       6  0.99
# 41       6  0.99
# 42       9  0.99
# 43      22  0.99
# 44      37  0.99
# 45      29  0.98
# 46      17  0.97
# 47      19  0.96
# 48      20  0.96
# 49      16  0.90
# 50      27  0.82
# 51      77  0.80
# 52      75  0.52
# 53       4  0.51

# %%
conn = sql.connect('eval.db')
result = pd.read_sql('SELECT * \
                     FROM eval \
                     WHERE return_value = 1', conn)

# %%
result
# Out:
#      index  true_positives  false_positives  true_negatives  false_negatives  \
# 0        0             172                0         1227918           194417
# 1        1             274               29         2670371          2095219
# 2        2               0                1         3396126          1474597
# 3        3             172                0         1226104           194417
# 4        4               0                1         2833009           285051
# ..     ...             ...              ...             ...              ...
# 186    186             564               14        15571956          1815734
# 187    187             166               19        12744090          1104285
# 188    188            1801                1        13496612          1755783
# 189    189            1018                7        15570239          1815280
# 190    190            3399              120        14336020          4572120
#
#      alarm_count  exploit_count  detection_rate  \
# 0            172            174        0.988506
# 1             51             98        0.520408
# 2              0            155        0.000000
# 3            172            174        0.988506
# 4              0            100        0.000000
# ..           ...            ...             ...
# 186          101            103        0.980583
# 187           98             98        1.000000
# 188          137            137        1.000000
# 189          103            103        1.000000
# 190          100            100        1.000000
#
#      consecutive_false_positives_normal  consecutive_false_positives_exploits  \
# 0                                     0                                     0
# 1                                    26                                     3
# 2                                     1                                     0
# 3                                     0                                     0
# 4                                     1                                     0
# ..                                  ...                                   ...
# 186                                  13                                     1
# 187                                  19                                     0
# 188                                   1                                     0
# 189                                   7                                     0
# 190                                 116                                     4
#
#      ...  precision_with_cfa  precision_with_syscalls               scenario  \
# 0    ...            1.000000                 1.000000         CVE-2017-7529/
# 1    ...            0.637500                 0.637500    Bruteforce_CWE-307/
# 2    ...            0.000000                 0.000000         CVE-2012-2122/
# 3    ...            1.000000                 1.000000         CVE-2017-7529/
# 4    ...            0.000000                 0.000000         CVE-2014-0160/
# ..   ...                 ...                      ...                    ...
# 186  ...            0.878261                 0.878261           PHP_CWE-434/
# 187  ...            0.837607                 0.837607         CVE-2019-5418/
# 188  ...            0.992754                 0.992754         CVE-2018-3760/
# 189  ...            0.936364                 0.936364           PHP_CWE-434/
# 190  ...            0.454545                 0.454545  SQL_Injection_CWE-89/
#
#     ngram  batch_size  embedding_size  return_value  thread_change_flag  \
# 0       4        1024               6             1                   1
# 1       4        1024               6             1                   1
# 2       4        1024               6             1                   1
# 3       6        1024               6             1                   1
# 4       6        1024               6             1                   1
# ..    ...         ...             ...           ...                 ...
# 186     6        1024               8             1                   1
# 187     8        1024               8             1                   1
# 188     8        1024               8             1                   1
# 189     8        1024               8             1                   1
# 190     8        1024               8             1                   1
#
#      time_delta  detection_time
# 0             0       15.711918
# 1             0       50.891472
# 2             0       47.202630
# 3             0       16.018071
# 4             0       34.263841
# ..          ...             ...
# 186           0      176.142924
# 187           0      127.150144
# 188           0      169.928648
# 189           0      162.617787
# 190           0      209.909717
#
# [191 rows x 21 columns]
